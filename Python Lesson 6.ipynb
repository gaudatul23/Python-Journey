# %% [markdown]
# # Day 6 #
#
# ## Sets ##

# %% [markdown]
# ### Companies use sets for: ###
#
# 1. Removing duplicate users
# 2. Comparing datasets
# 3. Finding common friends
# 4. Checking permissions
# 5. Fast searching
# 6. Recommendation systems
# 7. Data cleaning in AI/ML

# %% [markdown]
# ## What is set ##
#
# Imagine your attendance list
#
# atul , rahul , atul, om, rahul , raj.
#
# ### you don't want duplicate names ##
# so use set instead
#
# A set automatically removes duplicates

# %%
#A Set is an unordered, mutable collection of unique elements.
fruits = {"apple", "banana", "cherry"}

# Dictonary also contains same curly braces but it is a collection of key-value pairs.
 #set 
{"apple", "banana", "cherry"}

# dictonary
{"name"John", "age": 30, "city": "New York"}
# Out:
#   Cell In[5], line 6
#     fruits = {"apple", "banana", "cherry"}
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Features of Sets ##
#
# ### No Duplicated Values ##
# ### Unordered ##
# ### Mutable ###
# ### Can store different data types ###

# %%
# once a set is created, you cannot change its items, but you can add new items and also remove items from it.

# %%
thisset = {"apple", "banana", "cherry",True , 1, 2, }
print(thisset)

#The values True and 1 are considered the same value in sets, and are treated as duplicates:
# Out:
# {'cherry', True, 'apple', 2, 'banana'}

# %%
thisset = {"apple", "banana", "cherry", True, False,0 }
print(thisset)
#The values False and 0 are considered the same value in sets, and are treated as duplicates:
# Out:
# {'cherry', True, 'apple', False, 'banana'}

# %% [markdown]
# ## Length of the set ##

# %%
thisset = {"apple", "banana", "cherry"}
print(len(thisset))
# Out:
# 3

# %% [markdown]
# ## Set Data types ##

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

# %%
set4 = {"atul", 1, "male", 3, True, False}

# %% [markdown]
# ## type() ##

# %%
set = {"apple", "banana", "cherry"}
print(type(set))
# Out:
# <class 'set'>

# %% [markdown]
# ## Set Constructor ##
# It is also possible to use the set() constructor to make a set

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
#       2 print(thisset)
#
# TypeError: 'set' object is not callable

# %% [markdown]
# ## Access to Set Items ##
#
# You cannot access items in a set by referring to an index or a key.
#
# But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.

# %%
thisset = {"apple", "banana", "cherry"}
for x in thisset: 
  print(x)
# Out:
# cherry
# apple
# banana

# %%
thisset = {"apple", "banana", "cherry"}
print("banana" in thisset)

# to check if banana is present in the set or not, 
# we can use the keyword in. If banana is present in the set, it will return True otherwise it will return False.
# Out:
# True

# %% [markdown]
# ## Change items ##
#
# Once a set is created, you cannot change its items, but you can add new items

# %% [markdown]
# ## Add set Items ##

# %%
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print(thisset)

# why the order of the set elements is not the same as when we created the set?
# because sets are unordered, so the items will appear in a random order.
# Out:
# {'cherry', 'orange', 'apple', 'banana'}

# %% [markdown]
# ## Add Sets ##

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)
print(thisset)
# Out:
# {'cherry', 'pineapple', 'apple', 'banana', 'papaya', 'mango'}

# %% [markdown]
# ## add Iterable ##

# %%
thislist = ["kiwi", "orange"]
thisset = {"apple", "banana", "cherry"}

thisset.update(thislist)
print(thisset)
# Out:
# {'cherry', 'apple', 'banana', 'kiwi', 'orange'}

# %% [markdown]
# ## Remove Set Items ##

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana")
print(thisset)

#If the item to remove does not exist, remove() will raise an error.
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.discard("banana")
print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x) # removes a random item from the set, and returns the removed item.
print(thisset) # note that sets are unordered, so when using the pop() method, you will not know which item that gets removed.
# Out:
# cherry
# {'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.clear()
print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry"}
del thisset
print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 thisset = {"apple", "banana", "cherry"}
#       2 del thisset
# ----> 3 print(thisset)
#
# NameError: name 'thisset' is not defined

# %% [markdown]
# ## Loop Sets ##

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# apple
# banana

# %% [markdown]
# ## Join Set ##
# There are several ways to join two or more sets in Python.
#
# The union() and update() methods joins all items from both sets.
#
# The intersection() method keeps ONLY the duplicates.
#
# The difference() method keeps the items from the first set that are not in the other set(s).
#
# The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %% [markdown]
# ## Union ##
# The union() method returns a new set with all items from both sets.

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {1, 'b', 2, 3, 'a', 'c'}

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {1, 'b', 2, 3, 'a', 'c'}

# %% [markdown]
# ## Join Multiple Sets ##
#
# All the joining methods and operators can be used to join multiple sets.
#
# When using a method, just add more sets in the parentheses, separated by commas:

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = {"atul", "kumar", "singh"}
set4 = {"apple", "banana", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {'cherry', 1, 'b', 2, 3, 'a', 'apple', 'banana', 'kumar', 'atul', 'c', 'singh'}

# %%
set1 = {"a", "b" , "c"}
set2 = {"c", "d", "e"}
set3 = {"atul", "kumar", "singh"}
set4 = {"apple", "banana", "cherry"}

myset = set1 | set2 | set3 | set4
print(myset)
# Out:
# {'cherry', 'b', 'apple', 'a', 'banana', 'kumar', 'atul', 'c', 'e', 'd', 'singh'}

# %% [markdown]
# ## join Set and Tuple ##

# %%
x = {"apple", "banana", "cherry"}
y= {"google", "microsoft", "apple"}

z = x.union(y)
print(z)
# Out:
# {'cherry', 'apple', 'banana', 'microsoft', 'google'}

# %%
# can we join the set and the list 
list1 = ["a", "b" , "c"]
set1 = {"c", "d", "e"}

set3 = set1.union(list1)
print(set3)
# Out:
# {'b', 'a', 'c', 'e', 'd'}

# %% [markdown]
# ## Update ##
# The update() method inserts all items from one set into another.
#
# The update() changes the original set, and does not return a new set.

# %%
set1 = {"a", "b" , "c"}
set2 = {1,2,3 }

set1.update(set2)
print(set1)
# Out:
# {1, 'b', 2, 3, 'a', 'c'}

# %% [markdown]
# ## Intersection ##
# Keep ONLY the duplicates
#
# The intersection() method will return a new set, that only contains the items that are present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)

#The intersection_update() method will also keep ONLY the duplicates, 
# but it will change the original set instead of returning a new set.
# Out:
# {'apple'}

# %% [markdown]
# ## Difference ##
#
# The difference() method will return a new set that will contain only the items from the first set that are not present in the other set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %% [markdown]
# ## Symmetric Differnces ##
#
# The symmetric_difference() method will keep only the elements that are NOT present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'cherry', 'banana', 'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'cherry', 'banana', 'microsoft', 'google'}

# %% [markdown]
# ## Frozenset ##
#
# frozenset is an immutable version of a set.
#
# Like sets, it contains unique, unordered, unchangeable elements.
#
# Unlike sets, elements cannot be added or removed from a frozenset.

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'apple', 'banana'})
# <class 'frozenset'>

# %% [markdown]
# ## Frozenset Methods ##
#
# Being immutable means you cannot add or remove elements. However, frozensets support all non-mutating operations of sets.
#
# ### Method	Shortcut	###
#
# 1. copy()	 	Returns a shallow copy
# 2. difference()	-	Returns a new frozenset with the difference
# 3. intersection()	&	Returns a new frozenset with the intersection
# 4. isdisjoint()	 	Returns True if there is NO intersection between two frozensets
# 5. issubset()	<= / <	Returns True if this frozenset is a (proper) subset of another
# 6. issuperset()	>= / >	Returns True if this frozenset is a (proper) superset of      another
# 7. symmetric_difference()	^	Returns a new frozenset with the symmetric differences
# 8. union()	|	Returns a new frozenset containing the union

# %%
# ============================================================
#            PYTHON SETS - INTERVIEW QUESTIONS
#                 Easy -> Hard -> Tricky
# ============================================================

# Q1. What is a Set?
# Answer:
# A Set is an unordered, mutable collection of unique elements.

# Q2. Which brackets are used to create a Set?
# Answer:
# Curly braces {}
# Example:
# s = {1, 2, 3}

# Q3. How do you create an empty Set?
# Answer:
# s = set()
# NOTE: {} creates a dictionary, NOT a set.

# Q4. Does a Set allow duplicate values?
# Answer:
# No.
# Duplicate values are automatically removed.

# Q5. Is a Set ordered?
# Answer:
# No.
# The order is not guaranteed.

# Q6. Can we access Set elements using indexing?
# Answer:
# No.
# Sets do not support indexing or slicing.

# Q7. Can a Set store different data types?
# Answer:
# Yes.
# Example:
# {"Atul", 19, 72.5, True}

# Q8. Are Sets mutable?
# Answer:
# Yes.
# You can add and remove elements.

# Q9. Can a Set contain another Set?
# Answer:
# No.
# Sets are mutable and therefore unhashable.

# Q10. What is a Frozen Set?
# Answer:
# A frozenset is an immutable version of a set.

# -------------------- Methods --------------------

# Q11. add()
# Answer:
# Adds one element.
# Example:
# s.add(10)

# Q12. update()
# Answer:
# Adds multiple elements.
# Example:
# s.update([20, 30])

# Q13. remove()
# Answer:
# Removes an element.
# Raises KeyError if the element is not found.

# Q14. discard()
# Answer:
# Removes an element.
# Does NOT raise an error if the element is missing.

# Q15. pop()
# Answer:
# Removes and returns a random element.

# Q16. clear()
# Answer:
# Removes all elements.

# Q17. copy()
# Answer:
# Creates a shallow copy of the set.

# -------------------- Operations --------------------

# Q18. Union
# Answer:
# Combines both sets.
# Operator: |
# Method: union()

# Q19. Intersection
# Answer:
# Returns common elements.
# Operator: &
# Method: intersection()

# Q20. Difference
# Answer:
# Returns elements present in first set only.
# Operator: -
# Method: difference()

# Q21. Symmetric Difference
# Answer:
# Returns elements present in either set but not both.
# Operator: ^
# Method: symmetric_difference()

# -------------------- Membership --------------------

# Q22. How to check if an element exists?
# Answer:
# Use 'in'
# Example:
# 10 in s

# -------------------- Built-in Functions --------------------

# Q23. len(set)
# Answer:
# Returns the number of elements.

# Q24. max(set)
# Answer:
# Returns the largest element.

# Q25. min(set)
# Answer:
# Returns the smallest element.

# Q26. sum(set)
# Answer:
# Returns the sum of numeric elements.

# Q27. sorted(set)
# Answer:
# Returns a LIST, not a set.

# -------------------- Tricky Questions --------------------

# Q28.
# What is the output?
#
# {1,2,2,3}
#
# Answer:
# {1,2,3}

# Q29.
# What is the output?
#
# type({})
#
# Answer:
# <class 'dict'>

# Q30.
# What is the output?
#
# type(set())
#
# Answer:
# <class 'set'>

# Q31.
# Which is faster for searching?
# List or Set?
#
# Answer:
# Set
# Average Time Complexity: O(1)

# Q32.
# Can a list be added to a Set?
#
# Answer:
# No.
# Lists are mutable (unhashable).

# Q33.
# Can a tuple be added to a Set?
#
# Answer:
# Yes.
# Tuples are immutable (hashable).

# Q34.
# Difference between remove() and discard()?
#
# remove() -> Raises KeyError if item doesn't exist.
#
# discard() -> Does nothing if item doesn't exist.

# Q35.
# Difference between pop() in List and Set?
#
# List -> Removes element by index.
#
# Set -> Removes a random element.

# -------------------- Real-life Uses --------------------

# Q36. Where are Sets used?
#
# ✔ Removing duplicate data
# ✔ Finding common friends
# ✔ Permission management
# ✔ Data cleaning
# ✔ Recommendation systems
# ✔ Database operations
# ✔ Machine Learning preprocessing

# ============================================================
#          MOST IMPORTANT INTERVIEW QUESTIONS ⭐⭐⭐⭐⭐
#
# 1. List vs Tuple vs Set
# 2. Why are Sets unordered?
# 3. Why are duplicates not allowed?
# 4. remove() vs discard()
# 5. add() vs update()
# 6. Union vs Intersection vs Difference
# 7. {} vs set()
# 8. Why can't lists be stored in a Set?
# 9. What is Frozenset?
# 10. Why are Sets faster than Lists for searching?
#
# ============================================================
