# %% [markdown]
# # Day 7 #
#
# ## Python DIctionaries ##
#
# Imagine your'e storing student information
#
# Using a list
#
# student = [ "atul",19,"Mumbai",85]
#
# Now here what is 85?
# Marks ? , Age ? , Roll Number ?
#
# Nobody knows

# %%
# here we use the Dictionaries now 
student = {
    "name": "Atul",
    "age": 19,
    "city": "Mumbai",
    "marks": 85
}

# Now everything is crystal clear.

# That's why dictionaries exist.

# They store data as key-value pairs.


# A Dictionary is an ordered , mutable collection of key-value pairs

# %% [markdown]
# ## Features of Dictionaries ##
#
# 1. Key- Value Pairs
# 2. Ordered
# 3. Mutable
# 4. Key Must be Unique
# 5. Duplicate Values Are Allowed
# 6. Keys Must be Immutable ( Hashable )

# %%
student = {
    "name": "Atul",
    "age": 19
}
print(student)
# Out:
# {'name': 'Atul', 'age': 19}

# %%
student = {
    "name": "Atul",
    "age": 19,
    "city": "Mumbai"
}

print(student)
# Out:
# {'name': 'Atul', 'age': 19, 'city': 'Mumbai'}

# %%
student = {
    "name": "Atul"
}

student["name"] = "Rahul"

print(student)
# Out:
# {'name': 'Rahul'}

# %%
student = {
    "name": "Atul",
    "name": "Rahul"
}

print(student)
# Out:
# {'name': 'Rahul'}

# %%
student = {
    "name": "Atul",
    "friend": "Atul"
}
# this are perfectly valid becuase the key is unique and the value can be same.

# %%
student = {
    1: "One",
    "name": "Atul",
    (10, 20): "Coordinates",
    True: "Yes"
}

# %% [markdown]
# ## Data Types ##

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %% [markdown]
# ## Types ##
# From Python's perspective, dictionaries are defined as objects with the data type 'dict':
#
# <class 'dict'>

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %% [markdown]
# ## The dict() Constructor ##

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %% [markdown]
# ## Access Dictionary ##
# You can access the items of a dictionary by referring to its key name, inside square brackets:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict["model"])

# also write 
print(thisdict.get("model"))
# Out:
# Mustang

# %% [markdown]
# ## Keys ##
# The list of the keys is a view of the dictionary, meaning that any changes done to the dictionary will be reflected in the keys list.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

car["color"] = "white"

print(x) #after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %% [markdown]
# ## Values ##
# The values() method will return a list of all the values in the dictionary.
#
# The list of the values is a view of the dictionary, meaning that any changes done to the dictionary will be reflected in the values list.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()

print(x) #before the change

car["year"] = 2020

print(x) #after the change
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %% [markdown]
# ## Items ##
# The items() method will return each item in a dictionary, as tuples in a list.
#
# The returned list is a view of the items of the dictionary, meaning that any changes done to the dictionary will be reflected in the items list.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.items()

print(x) #before the change

car["year"] = 2020

print(x) #after the change
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2020)])

# %% [markdown]
# ## Check if Key Exists ##
# To determine if a specified key is present in a dictionary use the in keyword:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
if "model" in thisdict:
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %% [markdown]
# ## Change Dictionary Items ##
#
# ### Change Values ###
# You can change the value of a specific item by referring to its key name:

# %%
thisdict= {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["year"] = 2020
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# ## Update Dictionary ##
# The update() method will update the dictionary with the items from the given argument.
#
# The argument must be a dictionary, or an iterable object with key:value pairs.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# ## Add Dictionary Items ##
#
# ### Adding Items ###
# Adding an item to the dictionary is done by using a new index key and assigning a value to it:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"] = "red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
# While Updating the Dictionary we can also add new key-value pairs to it.

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})

# %% [markdown]
# ## Remove dictionary ##

# %%
# Removing Items from a Dictionary
# The pop() method removes the item with the specified key name:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
# popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead):
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
# The del keyword removes the item with the specified key name:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
} 
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict
print(thisdict) #this will cause an error because "thisdict" no longer exists.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       1 thisdict = {
#       2   "brand": "Ford",
#       3   "model": "Mustang",
#       4   "year": 1964
#       5 }
#       6 del thisdict
# ----> 7 print(thisdict)
#
# NameError: name 'thisdict' is not defined

# %%
# Clear()
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %% [markdown]
# ## Loop dictionaries ##
#
# You can loop through a dictionary by using a for loop.
#
# When looping through a dictionary, the return value are the keys of the dictionary, but there are methods to return the values as well.

# %%
# Print all key names in the dictionary, one by one:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for i in thisdict:
  print(i)
# Out:
# brand
# model
# year

# %%
# print all values in the dictionary, one by one:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for i in thisdict:
  print(thisdict[i])
# Out:
# Ford
# Mustang
# 1964

# %%
# You can also use the values() method to return values of a dictionary:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for i in thisdict.values():
  print(i)
# Out:
# Ford
# Mustang
# 1964

# %%
# You can also use the keys() method to return the keys of a dictionary:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for i in thisdict.keys():
  print(i)
# Out:
# brand
# model
# year

# %% [markdown]
# ## Copy a Dictionary ##
# You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.
#
# There are ways to make a copy, one way is to use the built-in Dictionary method copy().

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
# Another way to make a copy is to use the built-in function dict().
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# ## Nested Dictionaries ##
# A Dictionary can contain dictionaries this is called nested Dictionaries

# %%
animal = {
  "pet1":{
  "name": "Dog",
  "age": 5,
  "breed": "Labrador"
  },
  "pet2":{
  "name": "Cat",
  "age": 3,
  "breed": "Siamese"
  },
  "pet3":{
  "name": "Parrot",
  "age": 2,
  "breed": "Macaw"
  }
}

print(animal["pet1"]["name"])
print(animal)
print(animal["pet2"]["age"])
# Out:
# Dog
# {'pet1': {'name': 'Dog', 'age': 5, 'breed': 'Labrador'}, 'pet2': {'name': 'Cat', 'age': 3, 'breed': 'Siamese'}, 'pet3': {'name': 'Parrot', 'age': 2, 'breed': 'Macaw'}}
# 3

# %%
#Or, if you want to add three dictionaries into a new dictionary:
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

# %% [markdown]
# ## Access Item in Nested Dictionaries ##
# To access items from a nested dictionary, you use the name of the dictionaries, starting with the outer dictionary:

# %%
print(myfamily['child1'][ 'name'])
# Out:
# Emil

# %%
for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])
# Out:
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011

# %%
myfamily = {
    "child1": {
        "name": "Atul",
        "year": 2007
    },

    "child2": {
        "name": "Rahul",
        "year": 2005
    },

    "child3": {
        "name": "Om",
        "year": 2008
    }
}

for x, obj in myfamily.items(): # here we are using the items() method to get the key-value pairs of the dictionary. The key is stored in the variable x and the value is stored in the variable obj. The value is a dictionary itself, so we can use another for loop to iterate over the key-value pairs of the inner dictionary. The key is stored in the variable y and the value is stored in obj[y]. We can then print the key and value of the inner dictionary.
    print(x)  # here we are printing the key of the outer dictionary. The key is stored in the variable x. The value is a dictionary itself, so we can use another for loop to iterate over the key-value pairs of the inner dictionary. The key is stored in the variable y and the value is stored in obj[y]. We can then print the key and value of the inner dictionary.

    for y in obj: #here we are using the for loop to iterate over the key-value pairs of the inner dictionary. The key is stored in the variable y and the value is stored in obj[y]. We can then print the key and value of the inner dictionary.
        print(y + ':', obj[y])# here we are printing the key and value of the inner dictionary. The key is stored in the variable y and the value is stored in obj[y]. We can then print the key and value of the inner dictionary.
# Out:
# child1
# name: Atul
# year: 2007
# child2
# name: Rahul
# year: 2005
# child3
# name: Om
# year: 2008

# %% [markdown]
# ## Python Dictionary Method ##
#
# ### Method	Description ###
#
# 1. clear()	Removes all the elements from the dictionary
# 2. copy()	Returns a copy of the dictionary
# 3. fromkeys()	Returns a dictionary with the specified keys and value
# 4. get()	Returns the value of the specified key
# 5. items()	Returns a list containing a tuple for each key value pair
# 6. keys()	Returns a list containing the dictionary's keys
# 7. pop()	Removes the element with the specified key
# 8. popitem()	Removes the last inserted key-value pair
# 9. setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# 10. update()	Updates the dictionary with the specified key-value pairs
# 11. values()	Returns a list of all the values in the dictionary

# %%
# ============================================================
#      PYTHON DICTIONARY - INTERVIEW QUESTIONS (One Page)
# ============================================================


# Q1. What is a Dictionary?

student = {
    "name": "Atul",
    "age": 19,
    "city": "Mumbai"
}

print(student)


# ------------------------------------------------------------

# Q2. How do you access a value?

print(student["name"])
print(student.get("age"))


# ------------------------------------------------------------

# Q3. Difference between [] and get()

print(student["city"])          # Existing key
print(student.get("city"))      # Existing key

# print(student["marks"])       # KeyError
print(student.get("marks"))     # None


# ------------------------------------------------------------

# Q4. Change a value

student["age"] = 20
print(student)


# ------------------------------------------------------------

# Q5. Add a new key-value pair

student["course"] = "Python"

print(student)


# ------------------------------------------------------------

# Q6. Update multiple values

student.update({
    "city": "Pune",
    "marks": 95
})

print(student)


# ------------------------------------------------------------

# Q7. Remove an item

student.pop("marks")

print(student)


# ------------------------------------------------------------

# Q8. Remove the last inserted item

student.popitem()

print(student)


# ------------------------------------------------------------

# Q9. Delete entire dictionary

temp = {
    "a": 1,
    "b": 2
}

del temp

# print(temp)      # NameError


# ------------------------------------------------------------

# Q10. Clear dictionary

temp = {
    "a": 1,
    "b": 2
}

temp.clear()

print(temp)


# ------------------------------------------------------------

# Q11. Loop through Keys

student = {
    "name": "Atul",
    "age": 19,
    "city": "Mumbai"
}

for key in student:
    print(key)


# ------------------------------------------------------------

# Q12. Loop through Values

for value in student.values():
    print(value)


# ------------------------------------------------------------

# Q13. Loop through Keys and Values

for key, value in student.items():
    print(key, ":", value)


# ------------------------------------------------------------

# Q14. Copy Dictionary

copy_student = student.copy()

print(copy_student)


# ------------------------------------------------------------

# Q15. Nested Dictionary

family = {
    "child1": {
        "name": "Atul",
        "age": 19
    },

    "child2": {
        "name": "Rahul",
        "age": 22
    }
}

print(family)


# ------------------------------------------------------------

# Q16. Access Nested Dictionary

print(family["child1"]["name"])
print(family["child2"]["age"])


# ------------------------------------------------------------

# Q17. Loop Nested Dictionary

for member, info in family.items():

    print(member)

    for key in info:
        print(key, ":", info[key])


# ------------------------------------------------------------

# Q18. Check if key exists

print("name" in student)
print("salary" in student)


# ------------------------------------------------------------

# Q19. Length of Dictionary

print(len(student))


# ------------------------------------------------------------

# Q20. Dictionary Keys must be Unique

data = {
    "name": "Atul",
    "name": "Rahul"
}

print(data)


# ------------------------------------------------------------

# Q21. Duplicate Values are Allowed

data = {
    "person1": "Atul",
    "person2": "Atul"
}

print(data)


# ------------------------------------------------------------

# Q22. Can Different Data Types be Stored?

mixed = {
    "name": "Atul",
    "age": 19,
    "height": 5.9,
    "student": True
}

print(mixed)


# ------------------------------------------------------------

# Q23. Create Empty Dictionary

empty = {}

print(type(empty))


# ------------------------------------------------------------

# Q24. Create Dictionary using dict()

employee = dict(
    name="Rahul",
    salary=50000,
    city="Mumbai"
)

print(employee)


# ------------------------------------------------------------

# Q25. Merge Two Dictionaries

a = {
    "x": 1
}

b = {
    "y": 2
}

a.update(b)

print(a)


# ============================================================
#                MOST ASKED INTERVIEW QUESTIONS
# ============================================================

# 1. List vs Dictionary
# 2. [] vs get()
# 3. pop() vs popitem()
# 4. del vs clear()
# 5. keys(), values(), items()
# 6. Why must keys be unique?
# 7. Can values be duplicated?
# 8. Nested Dictionary
# 9. copy() vs =
# 10. update() vs assignment


# ============================================================
#                TIME COMPLEXITY (Interview)
# ============================================================

# Access by key      -> O(1)
# Insert             -> O(1)
# Delete             -> O(1)
# Search             -> O(1)
# Loop               -> O(n)


# ============================================================
#                END OF DICTIONARY CHEAT SHEET
# ============================================================
# Out:
# {'name': 'Atul', 'age': 19, 'city': 'Mumbai'}
# Atul
# 19
# Mumbai
# Mumbai
# None
# {'name': 'Atul', 'age': 20, 'city': 'Mumbai'}
# {'name': 'Atul', 'age': 20, 'city': 'Mumbai', 'course': 'Python'}
# {'name': 'Atul', 'age': 20, 'city': 'Pune', 'course': 'Python', 'marks': 95}
# {'name': 'Atul', 'age': 20, 'city': 'Pune', 'course': 'Python'}
# {'name': 'Atul', 'age': 20, 'city': 'Pune'}
# {}
# name
# age
# city
# Atul
# 19
# Mumbai
# name : Atul
# age : 19
# city : Mumbai
# {'name': 'Atul', 'age': 19, 'city': 'Mumbai'}
# {'child1': {'name': 'Atul', 'age': 19}, 'child2': {'name': 'Rahul', 'age': 22}}
# Atul
# 22
# child1
# name : Atul
# age : 19
# child2
# name : Rahul
# age : 22
# True
# False
# 3
# {'name': 'Rahul'}
# {'person1': 'Atul', 'person2': 'Atul'}
# {'name': 'Atul', 'age': 19, 'height': 5.9, 'student': True}
# <class 'dict'>
# {'name': 'Rahul', 'salary': 50000, 'city': 'Mumbai'}
# {'x': 1, 'y': 2}

# %%
student = {
    "name": "Atul"
}

print(student.get("age"))
# Out:
# None
