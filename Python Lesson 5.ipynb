# %% [markdown]
# ## Python Tuples ##

# %% [markdown]
# ### Tuples ###
#
# Imagine you have your birth date.
#
# 21 / 08 / 2006
#
# Can you change your birth date?
#
# No.
#
# Some data should never change.
#
# Python says:
#
# "If your data should remain fixed, store it in a Tuple."
#
# A Tuple is an ordered and immutable collection used to store multiple values.

# %%
#Example 
fruits = ("Apple", "Banana", "Mango")

# %%
# real - Life Example 
# Coordinateds
location = (19.0760, 72.8777)

#RGB Colors 
red = (255, 0, 0)

#Day of the Weeks 
days = (
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
    "Sunday"
)

# %% [markdown]
# ### Tuples Items ###
#
# Tuple items are ordered, unchangeable, and allow duplicate values.
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
#
# ### Ordered ###
#
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
#
# ### Unchangeabe ###
#
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
#
# ### Allow Duplicates ###
#
# Since tuples are indexed, they can have items with the same value:

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %% [markdown]
# ## Tuple Length ##
# To determine how many items a tuple has use the len() function

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# ## Create Tuple with one item ##
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple.

# %%
thistuple=("apple",)
print(type(thistuple))

# not a tuple 
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# ## Tuple Items _ Data Types ##
# A tuple with strings, integers and boolean values:

# %%
tuple1 = ("abc", 34, True, 40, "male")

# %% [markdown]
# ## Access Tuple Items ##
# You can access tuple item by referringn to the index number , inside square brackets

# %%
thistuple= ("apple", "banana", "cherry")
print(thistuple[1])

# same as Negative indexing 
print(thistuple[-1])
# Out:
# banana
# cherry

# %% [markdown]
# ## Range of Indexes ##
#
# You can specify a range of indexes by specifying where to start and where to end the range.
# When specifying a range, the return value will be a new tuple with the specified items.

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])

# also works
print(thistuple[-4:-1])

# also works
print(thistuple[:4])

# also works
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi')
# ('orange', 'kiwi', 'melon')
# ('apple', 'banana', 'cherry', 'orange')
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %% [markdown]
# ## check if Item Exist ##

# %%
thistuple= ("apple", "banana", "cherry")
if "apple" in thistuple:
    print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %% [markdown]
# ## Change the Tuple Values ##
#
# Once a tuple is created , you cannot change it values.
# Tuples are unchangeable or immutable as it is also called.
#
# But there is a workaround. You can convert the tuple into a list, change the list and convert the list back into a tuple.

# %%
# Exmaple 
x = ("apple", "banana", "cherry")
y = list(x) 
y[1] = "kiwi"
x = tuple(y)

print(x)

# one more example

personal_info = ("John", 25, "New York","phone no")
emergency_contact = list(personal_info)
emergency_contact[3]= "0987654321"
personal_info = tuple(emergency_contact)
print(personal_info)
# Out:
# ('apple', 'kiwi', 'cherry')
# ('John', 25, 'New York', '0987654321')

# %% [markdown]
# ## Add Items ##
# Since tuples are immutable, they do not have a built-in append() method, but there are other ways to add items to a tuple.
#
#
# 1. Convert into a list: Just like the workaround for changing a tuple, you can convert it into a list, add your item(s), and convert it back into a tuple.

# %%
thistuple= ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# 2. Add tuple to a tuple. You are allowed to add tuples to tuples, so if you want to add one item, (or many), create a new tuple with the item(s), and add it to the existing tuple:

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# ## Remove items ##
#
# Tuples are unchangeable so you cannot remove items from it but you can  use the same workaround as we use for changing and adding tuple items:

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)


# delete the tuple completely

thistuple= ( "apple", "banana", "cherry")
del thistuple
print(thistuple) # this will raise an error because the tuple no longer exists
# Out:
# ('banana', 'cherry')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 12
#      10 thistuple= ( "apple", "banana", "cherry")
#      11 del thistuple
# ---> 12 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %% [markdown]
# ## Unpack tuples ##
#
# When we create a tuple we normally assign values to it this called packing a tuple

# %%
# packing a tuple 
fruits = ("apple", "banana", "cherry")

# %%
# but in python we are also allowed to extract the values back into variables.
#  THis is called unpacking
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)

#  The number of variables must match the number of values in the tuple, if not,
#  you must use an asterisk to collect the remaining values as a list.
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Using Asterisk ##
#
# If the number of variable is less than the number of values you can add an * to the variable
# name and the values will be assigned to the variable as a list

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)

# Now here why they values of red are in list ? were as we are using tuples 
#  The reason is that the values of red are not unpacked into a tuple, but rather collected into a list.
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %% [markdown]
# ## Loop Tuples ##

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Loops through the index Numbers ##

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Using a while Loop ##
# You can loop through the tuple items by using a while loop.
#
# Use the len() function to determine the length of the tuple, then start at 0 and loop your way through the tuple items by referring to their indexes.
#
# Remember to increase the index by 1 after each iteration.

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Join Tuples ##

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# ## Multiply Tuples ##

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
# Q1. What is a Tuple?
# Answer:
# A tuple is an ordered, immutable collection that can store
# multiple values.

# Q2. Why use Tuple instead of List?
# Answer:
# Because tuples cannot be modified after creation, making them
# safer for fixed data.

# Q3. Difference between List and Tuple?
# List  -> [] -> Mutable
# Tuple -> () -> Immutable

# Q4. Are tuples ordered?
# Answer:
# Yes, elements maintain their insertion order.

# Q5. Do tuples allow duplicate values?
# Answer:
# Yes.

# Q6. Can tuples store multiple data types?
# Answer:
# Yes.
# Example:
# ("Atul", 19, 72.5, True)

# Q7. How do you create a tuple?
# Answer:
# t = (10, 20, 30)

# Q8. How do you create a tuple with one element?
# Answer:
# t = (10,)
# (Comma is compulsory.)

# Q9. How do you access tuple elements?
# Answer:
# t[0], t[1], t[-1]

# Q10. Does tuple support negative indexing?
# Answer:
# Yes.

# Q11. Does tuple support slicing?
# Answer:
# Yes.
# Example:
# t[1:4]

# Q12. Can we modify a tuple?
# Answer:
# No.
# Tuples are immutable.

# Q13. How can we update a tuple?
# Answer:
# Convert tuple → list
# Modify list
# Convert list → tuple

# Q14. Can we delete a tuple?
# Answer:
# Yes.
# del tuple_name

# Q15. How do you loop through a tuple?
# Answer:
# for item in tuple:
#     print(item)

# Q16. How do you join two tuples?
# Answer:
# t3 = t1 + t2

# Q17. How do you repeat a tuple?
# Answer:
# t * 3

# Q18. What is Tuple Packing?
# Answer:
# Packing multiple values into one tuple.
# Example:
# student = ("Atul", 19, "Mumbai")

# Q19. What is Tuple Unpacking?
# Answer:
# Extracting tuple values into variables.
# Example:
# name, age, city = student

# Q20. What is Extended Unpacking?
# Answer:
# Example:
# a, *b, c = (1,2,3,4,5)

# Q21. What methods are available in tuple?
# Answer:
# count()
# index()

# Q22. What does count() do?
# Answer:
# Returns how many times a value appears.

# Q23. What does index() do?
# Answer:
# Returns the first index of a value.

# Q24. Can a tuple contain another tuple?
# Answer:
# Yes.
# Example:
# ((1,2), (3,4))

# Q25. Can a tuple contain a list?
# Answer:
# Yes.

# Q26. If tuple contains a list, can the list be modified?
# Answer:
# Yes.
# Tuple is immutable, but the list inside it is mutable.

# Q27. What is the output?
# type((5))
# Answer:
# <class 'int'>

# Q28. What is the output?
# type((5,))
# Answer:
# <class 'tuple'>

# Q29. Difference between == and is ?
# ==
# Compares values.
#
# is
# Compares memory location (object identity).

# Q30. Does sorted(tuple) return a tuple?
# Answer:
# No.
# It returns a LIST.

# Q31. Can tuple be used as dictionary keys?
# Answer:
# Yes.
# Because tuples are immutable.

# Q32. Is tuple faster than list?
# Answer:
# Yes.
# Tuples are generally faster and use less memory.

# Q33. What are real-life uses of tuples?
# Answer:
# ✔ GPS Coordinates
# ✔ RGB Colors
# ✔ Database Records
# ✔ Configuration Settings
# ✔ Fixed Constants
